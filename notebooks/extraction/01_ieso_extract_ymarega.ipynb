# %%
import pandas as pd

# %%
url = "https://reports-public.ieso.ca/public/Demand/PUB_Demand.csv"
df = pd.read_csv(url, comment="\\")
print(url)
df
# Out:
# https://reports-public.ieso.ca/public/Demand/PUB_Demand.csv
#             Date  Hour  Market Demand  Ontario Demand
# 0     2026-01-01     1          19489           16526
# 1     2026-01-01     2          19317           16374
# 2     2026-01-01     3          19326           16242
# 3     2026-01-01     4          19070           16155
# 4     2026-01-01     5          19109           16180
# ...          ...   ...            ...             ...
# 1676  2026-03-11    21          19595           17495
# 1677  2026-03-11    22          19364           16763
# 1678  2026-03-11    23          18800           16087
# 1679  2026-03-11    24          18596           15517
# 1680  2026-03-12     1          18095           15164
#
# [1681 rows x 4 columns]

# %%
url = "https://reports-public.ieso.ca/public/DemandZonal/PUB_DemandZonal.csv"
df = pd.read_csv(url)
print(url)
df
# Out:
# https://reports-public.ieso.ca/public/DemandZonal/PUB_DemandZonal.csv
#           \\Hourly Zonal Demand Report Unnamed: 1      Unnamed: 2 Unnamed: 3  \
# 0     \\Created at 2026-03-12 08:00:14        NaN             NaN        NaN
# 1                           \\For 2026        NaN             NaN        NaN
# 2                                 Date       Hour  Ontario Demand  Northwest
# 3                           2026-01-01          1           16526        688
# 4                           2026-01-01          2           16374        686
# ...                                ...        ...             ...        ...
# 1678                        2026-03-11         20           18115        556
# 1679                        2026-03-11         21           17495        554
# 1680                        2026-03-11         22           16763        548
# 1681                        2026-03-11         23           16087        538
# ...

# %%
url = "https://reports-public.ieso.ca/public/DAHourlyEnergyLMP/PUB_DAHourlyEnergyLMP_20251212.csv"
df = pd.read_csv(url)
print(url)
df
# Out:
# https://reports-public.ieso.ca/public/DAHourlyEnergyLMP/PUB_DAHourlyEnergyLMP_20251212.csv
#                                                           CREATED AT 2025/12/11 13:33:16 FOR 2025/12/12
# Delivery Hour Pricing Location   LMP    Energy Loss Price                       Energy Congestion Price
# 1             ABITIBISF-LT.AG_T1 142.52 7.41                                                       0.00
# 2             ABITIBISF-LT.AG_T1 122.00 5.98                                                       0.00
# 3             ABITIBISF-LT.AG_T1 103.57 5.18                                                       0.00
# 4             ABITIBISF-LT.AG_T1 93.61  4.68                                                       0.00
# ...                                                                                                 ...
# 20            ZURICH-LT.AG_T1    195.50 -4.50                                                      0.00
# ...

# %%
url = ""
df = pd.read_csv(url)
print(url)
df

# %%
## Bon lien ###url = "https://reports-public.ieso.ca/public/IntertieScheduleFlow/PUB_IntertieScheduleFlow.xml"
df = pd.read_csv(url)
print(url)
df

# Mauvais lien #https://reports-public.ieso.ca/public/IntertieScheduleFlow/PUB_IntertieScheduleFlow.csv
## Les donnees d'INertieScheduleFlow sont en XML, pas en csv,
# Out:
# https://reports-public.ieso.ca/public/IntertieScheduleFlow/PUB_IntertieScheduleFlow.xml
#                   <?xml version="1.0" encoding="UTF-8"?>
# 0      <?xml-stylesheet type="text/xsl" href="https:/...
# 1                                         <IMODocHeader>
# 2      <DocTitle>Intertie Schedule and Flow Report</D...
# 3                           <DocRevision>2</DocRevision>
# 4                                   <DocConfidentiality>
# ...                                                  ...
# 22602                                          </Actual>
# 22603                                         </Actuals>
# 22604                                          </Totals>
# 22605                                      </IMODocBody>
# 22606                                     </IMODocument>
#
# [22607 rows x 1 columns]

# %%
# Mauvais lien "https://reports-public.ieso.ca/public/GenOutputbyFuelHourly/PUB_GenOutputbyFuelHourly.csv


url = ""
df = pd.read_csv(url)
print(url)
df

## Bon lien https://reports-public.ieso.ca/public/GenOutputbyFuelHourly/PUB_GenOutputbyFuelHourly.xml

# %%
url = ""
df = pd.read_csv(url)
print(url)
df
